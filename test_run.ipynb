# %%
import numpy as np
import os
import timeit

def extract_image_from_file(filePath, NewPath):
    for path in os.listdir(filePath):
        temp = []      
        expath = os.path.join(filePath, path)
        newPath = os.path.join(NewPath, path)
        temp.append(expath)
        for file in temp: 
            if file.endswith((".jpg", ".png", ".jpeg")):
                print(expath)
        
        # print(expath)
        # os.replace(expath, newPath)

# %%
file_path = os.path.join('dataset', 'a.i. faces.v2i.multiclass', 'test')
New_Path =  os.path.join('data', 'Neg_img')

# %%
extract_image_from_file(file_path, New_Path)

# %%
def extract_anchor_and_pos_image(filepath, NewPath):
    for file in os.listdir(filepath):
        expath = os.path.join(filepath, file)
        newpath = os.path.join(NewPath, file)
        if file.startswith('1--') and file.lower().endswith((".jpg", "jpeg", ".png")):
            print(file)
            os.replace(expath, newpath)

# %%
file_path = os.path.join('dataset', 'doan3.v10i.folder', 'train', 'quen')
New_Path =  os.path.join('data', 'Anchor_img')
extract_anchor_and_pos_image(file_path, New_Path)

# %%
Pos_Path = os.path.join('data', 'Pos_img')
extract_anchor_and_pos_image(file_path, Pos_Path)
